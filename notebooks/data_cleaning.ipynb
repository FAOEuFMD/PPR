# %%
import pandas as pd

data = pd.read_excel('/Users/user/Documents/Work_Studies/FAO_Projects/PPR/data/ppr_outbreaks-adis.xls')

data.head()
# Out:
#            Reference Country/Territory     Type  \
# 0  GR-PPR-2024-00072            Greece  Primary
# 1  GR-PPR-2024-00071            Greece  Primary
# 2  GR-PPR-2024-00070            Greece  Primary
# 3  GR-PPR-2024-00069            Greece  Primary
# 4  GR-PPR-2024-00068            Greece  Primary
#
#                                     Disease name Local Authority Unit (LAU)  \
# 0  Peste des petits ruminants virus (Inf. with)                         NaN
# 1  Peste des petits ruminants virus (Inf. with)                         NaN
# 2  Peste des petits ruminants virus (Inf. with)                         NaN
# 3  Peste des petits ruminants virus (Inf. with)                         NaN
# 4  Peste des petits ruminants virus (Inf. with)                         NaN
#
#   Submitted on                    Administrative division level 1  \
# 0   2024-09-17                        Thessaly and Central Greece
# 1   2024-09-13                        Thessaly and Central Greece
# 2   2024-09-13                        Thessaly and Central Greece
# 3   2024-09-12  Peloponnese, Western Greece and the Ionian Isl...
# 4   2024-09-12  Peloponnese, Western Greece and the Ionian Isl...
#
#   Administrative division level 2 Administrative division level 3  \
# 0                        Thessaly                         Larissa
# 1                        Thessaly                           Tempi
# 2                        Thessaly                           Tempi
# 3                     Peloponnese                         Sikyona
# 4                     Peloponnese                         Sikyona
#
#    Outbreak occurring inside an already restricted zone  ...  Category 6  \
# 0                                               True     ...         NaN
# 1                                               True     ...         NaN
# 2                                               True     ...         NaN
# 3                                               True     ...         NaN
# 4                                               True     ...         NaN
#
#    Subcategory 6 Test name 6  Test type 6  Laboratory name 6  \
# 0            NaN         NaN          NaN                NaN
# 1            NaN         NaN          NaN                NaN
# 2            NaN         NaN          NaN                NaN
# 3            NaN         NaN          NaN                NaN
# 4            NaN         NaN          NaN                NaN
#
#    Laboratory type 6  Species 6  Result date 6  Result type 6 Reported to
# 0                NaN        NaN            NaN            NaN          EU
# 1                NaN        NaN            NaN            NaN          EU
# 2                NaN        NaN            NaN            NaN          EU
# 3                NaN        NaN            NaN            NaN          EU
# 4                NaN        NaN            NaN            NaN          EU
#
# [5 rows x 81 columns]

# %%
data.columns
# Out:
# Index(['Reference', 'Country/Territory', 'Type', 'Disease name',
#        'Local Authority Unit (LAU)', 'Submitted on',
#        'Administrative division level 1', 'Administrative division level 2',
#        'Administrative division level 3',
#        'Outbreak occurring inside an already restricted zone', 'Latitude',
#        'Longitude', 'Species 1', 'Susceptible 1', 'Cases 1', 'Dead 1',
#        'Killed 1', 'Slaughtered 1', 'Outbreak year', 'Suspicion/Start date',
#        'Confirmation date', 'Status Continuing/Resolved', 'Suspicion',
#        'Clinical signs', 'Diagnostic tests', 'Necropsy', 'Category 1',
#        'Subcategory 1', 'Test name 1', 'Test type 1', 'Laboratory name 1',
#        'Laboratory type 1', 'Species 1.1', 'Result date 1', 'Result type 1',
#        'Category 2', 'Subcategory 2', 'Test name 2', 'Test type 2',
#        'Laboratory name 2', 'Laboratory type 2', 'Species 2', 'Result date 2',
#        'Result type 2', 'Category 3', 'Subcategory 3', 'Test name 3',
#        'Test type 3', 'Laboratory name 3', 'Laboratory type 3', 'Species 3',
#        'Result date 3', 'Result type 3', 'Category 4', 'Subcategory 4',
#        'Test name 4', 'Test type 4', 'Laboratory name 4', 'Laboratory type 4',
#        'Species 4', 'Result date 4', 'Result type 4', 'Category 5',
#        'Subcategory 5', 'Test name 5', 'Test type 5', 'Laboratory name 5',
#        'Laboratory type 5', 'Species 5', 'Result date 5', 'Result type 5',
#        'Category 6', 'Subcategory 6', 'Test name 6', 'Test type 6',
#        'Laboratory name 6', 'Laboratory type 6', 'Species 6', 'Result date 6',
#        'Result type 6', 'Reported to'],
#       dtype='object')

# %%
data.isna().all()
# Out:
# Reference                     False
# Country/Territory             False
# Type                          False
# Disease name                  False
# Local Authority Unit (LAU)    False
#                               ...
# Laboratory type 6              True
# Species 6                      True
# Result date 6                  True
# Result type 6                  True
# Reported to                   False
# Length: 81, dtype: bool

# %%
data[data.isna().all()[1] == False]
# Out:
# /var/folders/sl/mv8yjf9108790gsptkrpqx3w0000gn/T/ipykernel_72308/1587205608.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data[data.isna().all()[1] == False]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/DSPT14/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data[data.isna().all()[1] == False]
#
# File ~/.pyenv/versions/DSPT14/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.pyenv/versions/DSPT14/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: True
